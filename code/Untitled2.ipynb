# %%
latitudes = [37.7749, 37.7749, 37.7750, 37.7750, 37.7750, 37.7751, 37.7751, 37.7751, 37.7751, 37.7752]
longitudes = [-122.4194, -122.4193, -122.4193, -122.4192, -122.4191, -122.4190, -122.4189, -122.4188, -122.4187, -122.4186]

import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Create a hexbin plot
hb = ax.hexbin(longitudes, latitudes, gridsize=20, cmap='inferno', mincnt=1)

# Add a colorbar
cb = fig.colorbar(hb, ax=ax)

# Set the x and y axis labels
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Set the title of the plot
ax.set_title('Heatmap of Points')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.ndimage.filters import gaussian_filter


def myplot(x, y, s, bins=1000):
    heatmap, xedges, yedges = np.histogram2d(x, y, bins=bins)
    heatmap = gaussian_filter(heatmap, sigma=s)

    extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]
    return heatmap.T, extent


fig, axs = plt.subplots(2, 2)

# Generate some test data
x = np.random.randn(1000)
y = np.random.randn(1000)

sigmas = [0, 16, 32, 64]

for ax, s in zip(axs.flatten(), sigmas):
    if s == 0:
        ax.plot(x, y, 'k.', markersize=5)
        ax.set_title("Scatter plot")
    else:
        img, extent = myplot(x, y, s)
        ax.imshow(img, extent=extent, origin='lower', cmap=cm.jet)
        ax.set_title("Smoothing with  $\sigma$ = %d" % s)

plt.show()
# Out:
# C:\Users\Greig\AppData\Local\Temp\ipykernel_13184\1649636292.py:4: DeprecationWarning: Please use `gaussian_filter` from the `scipy.ndimage` namespace, the `scipy.ndimage.filters` namespace is deprecated.
#   from scipy.ndimage.filters import gaussian_filter

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the number of bins
num_bins = 20

# Create a 2D histogram
heatmap, x_edges, y_edges = np.histogram2d(latitudes, longitudes, bins=num_bins)

# Create the x and y axis ticks
x_ticks = (x_edges[:-1] + x_edges[1:]) / 2
y_ticks = (y_edges[:-1] + y_edges[1:]) / 2

# Create the plot
fig, ax = plt.subplots()
im = ax.imshow(heatmap, cmap='inferno', extent=[x_edges[0], x_edges[-1], y_edges[0], y_edges[-1]], aspect='auto')
cb = fig.colorbar(im, ax=ax)

# Set the x and y axis labels
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Set the title of the plot
ax.set_title('Heatmap of Points')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Create a hexbin plot
hb = ax.hexbin(longitudes, latitudes, gridsize=20, cmap='inferno', mincnt=1, extent=[min(longitudes), max(longitudes), min(latitudes), max(latitudes)])

# Add a colorbar
cb = fig.colorbar(hb, ax=ax)

# Set the x and y axis labels
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Set the title of the plot
ax.set_title('Heatmap of Points')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Create a hexbin plot
hb = ax.hexbin(longitudes, latitudes, gridsize=20, cmap='inferno', mincnt=1, alpha=0.7, extent=[min(longitudes), max(longitudes), min(latitudes), max(latitudes)])

# Make the areas with count = 0 transparent
hb.set_alpha(0.0)

# Add a colorbar
cb = fig.colorbar(hb, ax=ax)

# Set the x and y axis labels
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')

# Set the title of the plot
ax.set_title('Heatmap of Points')

# Display the plot
plt.show()
