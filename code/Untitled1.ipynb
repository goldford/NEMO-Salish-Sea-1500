# %%
import pickle

# %%
hindcast_array = pickle.load(open('C:/temp/Zooplankton_Time_Series_CastCTD_1996-11-07_2240h.pickle', 'rb'))

# %%
hindcast_array
# Out:
# {'z': masked_array(data=[0.4998191297054291, 1.4994596242904663,
#                     2.49910569190979, 3.498762369155884, 4.498440265655518,
#                     5.498157978057861, 6.497955322265625,
#                     7.497905254364014, 8.49815559387207, 9.498990058898926,
#                     10.500959396362305, 11.505141258239746,
#                     12.513630867004395, 13.53050708770752,
#                     14.563703536987305, 15.628623008728027,
#                     16.75510025024414, 18.0006103515625, 19.4747257232666,
#                     21.38222885131836, 24.091524124145508,
#                     28.21968650817871, 34.673187255859375,
#                     44.50159454345703, 58.46314239501953, 76.5578384399414,
#                     98.02742767333984, 121.82235717773438,
#                     142.81588745117188],
#               mask=[False, False, False, False, False, False, False, False,
# ...

# %%
import scipy.io

# %%
mat = scipy.io.loadmat('C:/temp/LH_class4_RUN203_hindcast.mat')

# %%
mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: posix, Created on: Mon Mar 27 21:43:17 2023',
#  '__version__': '1.0',
#  '__globals__': [],
#  'class4': array([[(array([[(array([[(array([[48.873]], dtype=float32), array([[-123.292]], dtype=float32), array([[723181.29185185]]), array([[734868.41777778]]), array(['/project/6006412/goldford/OBS-WEST/LH/active_pass_LH.nc'],
#                                dtype='<U55'), array([[(array([[8.44981801],
#                                         [8.26625984],
#                                         [8.33611941],
#                                         ...,
#                                         [6.61886794],
#                                         [6.55316801],
#                                         [6.5631474 ]]), array([[28.78383296],
#                                         [28.5622101 ],
#                                         [28.70637396],
#                                         ...,
# ...
