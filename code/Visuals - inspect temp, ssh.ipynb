# %%
#%matplotlib notebook
import matplotlib.pyplot as plt
import netCDF4 as nc
import numpy as np
import cmocean
import os
import pandas as pd

# %%
with nc.Dataset('C://Users//Greig//Downloads//SalishSea1500-RUN200_1d_grid_T_19900819-19900819.nc') as ncf:
    temper = ncf.variables['votemper'][0,...]

#with nc.Dataset('C://temp//output.abort.nc') as ncf:
#    ssh = ncf.variables['sossheig'][0,...]   
#    temper = ncf.variables['votemper'][0,...]


with nc.Dataset('C://Users//Greig//Documents//GitHub//NEMO-Salish-Sea-2021//data//grid//coordinates_salishsea_1500m.nc') as ncf:
    nlat = ncf.variables['gphit'][0,...]   # neglected the 1/2 grid box shift here
    nlon = ncf.variables['glamt'][0,...]

# %%
cm = 5

plt.close(); 
plt.figure(figsize=(12,12))
plt.subplot(1,1,1)
plt.pcolormesh(nlon, nlat, temper[0,:,:])
#plt.pcolormesh(ma_temper,shading='auto')
#plt.plot(ncst[:,0],ncst[:,1],'k',linewidth=0.5)
plt.xlim([-126,-122]); plt.ylim([47,51])
#plt.clim([0,cm]); 
plt.colorbar()
plt.title('')

#   plt.subplot(1,3,2)
#   plt.pcolormesh(nlon,nlat,esn_NEMO1*tmask,shading='auto')
#   plt.plot(ncst[:,0],ncst[:,1],'k',linewidth=0.5)
#   plt.xlim([-126,-122]); plt.ylim([47,51])
#   plt.clim([0,cm]); plt.colorbar()
#   plt.title('ERA5 before on NEMO grid')

#   plt.subplot(1,3,3)
#   plt.pcolormesh(nlon,nlat,esn_NEMO2*tmask,shading='auto')
#   plt.plot(ncst[:,0],ncst[:,1],'k',linewidth=0.5)
#   plt.xlim([-126,-122]); plt.ylim([47,51])
#   plt.clim([0,cm]); plt.colorbar()
#   plt.title('ERA5 after on NEMO grid') 

#   plt.suptitle(str(month) + "- Before / After ERA5 Adjustment")
#   plt.savefig('deleteme_3compare_' + str(month) + '_' + str(year_start) + "to" + str(year_end) + '.png')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
# Text(0.5, 1.0, '')

# %%
temp.shape
# Out:
# (40, 299, 132)
